# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('./data/mobile.bg-offers-2024-02-17.csv')

# %%
data
# Out:
#           Марка  Модел Категория Дата на производство    Тип двигател  \
# 0          Opel  Combo     Пикап          март 2005г.         Дизелов
# 1          Opel  Combo     Пикап        август 2006г.         Дизелов
# 2          Opel  Combo     Пикап        август 2007г.        Бензинов
# 3          Opel  Combo     Пикап       ноември 2004г.        Бензинов
# 4          Opel  Combo       Ван           юни 2006г.         Дизелов
# ...         ...    ...       ...                  ...             ...
# 119520  Peugeot    308    Хечбек        август 2022г.         Дизелов
# 119521  Peugeot    308    Хечбек          март 2023г.         Дизелов
# 119522  Peugeot    308    Хечбек      февруари 2022г.         Дизелов
# 119523  Peugeot    308    Хечбек      декември 2022г.  Plug-in хибрид
# 119524  Peugeot    308    Хечбек      февруари 2008г.         Дизелов
#
#        Скоростна кутия Кубатура [куб.см]   Мощност Евростандарт Пробег [км]  \
# 0                Ръчна               NaN   75 к.с.          NaN   232000 км
# 1                Ръчна       1248 куб.см   69 к.с.       Евро 4   233013 км
# 2                Ръчна       1600 куб.см   93 к.с.       Евро 4   193674 км
# 3                Ръчна       1400 куб.см   90 к.с.       Евро 4   189672 км
# 4                Ръчна       1686 куб.см  101 к.с.       Евро 4   200000 км
# ...                ...               ...       ...          ...         ...
# 119520     Автоматична       1500 куб.см  130 к.с.       Евро 6     7174 км
# 119521     Автоматична       1499 куб.см  130 к.с.       Евро 6     5950 км
# 119522     Автоматична       1500 куб.см  130 к.с.       Евро 6    20600 км
# 119523     Автоматична               NaN  180 к.с.       Евро 6    11600 км
# 119524           Ръчна       1600 куб.см       NaN          NaN   166000 км
#
#         ...                                            Комфорт  \
# 0       ...  Датчик за светлина, Ел. Огледала, Ел. Стъкла, ...
# 1       ...                Регулиране на волана, Стерео уредба
# 2       ...  Ел. Огледала, Ел. Стъкла, Ел. усилвател на вол...
# 3       ...  Датчик за светлина, Ел. Огледала, Ел. Стъкла, ...
# 4       ...  Ел. Огледала, Ел. Стъкла, Климатик, Мултифункц...
# ...     ...                                                ...
# 119520  ...  Auto Start Stop function, Bluetooth \ handsfre...
# 119521  ...  Auto Start Stop function, Bluetooth \ handsfre...
# 119522  ...  Auto Start Stop function, Bluetooth \ handsfre...
# 119523  ...  Auto Start Stop function, Bluetooth \ handsfre...
# 119524  ...                                                NaN
#
#                                                     Други  \
# 0                                        Бартер, Нов внос
# 1             Напълно обслужен, Нов внос, Сервизна книжка
# 2                               Нов внос, Сервизна книжка
# 3             Напълно обслужен, Нов внос, Сервизна книжка
# 4                       Лизинг, Нов внос, Сервизна книжка
# ...                                                   ...
# 119520  Лизинг, Напълно обслужен, С регистрация, Серви...
# 119521                              Лизинг, С регистрация
# 119522  Лизинг, Напълно обслужен, С регистрация, Серви...
# 119523  Лизинг, Напълно обслужен, С регистрация, Серви...
# 119524                                                NaN
#
#                                                 Екстериор  \
# 0                                              2(3) Врати
# 1                                     4(5) Врати, Металик
# 2                                                 Металик
# 3                             4(5) Врати, Металик, Теглич
# 4        4(5) Врати, Рейлинг на покрива, Халогенни фарове
# ...                                                   ...
# 119520  4(5) Врати, LED фарове, Лети джанти, Металик, ...
# 119521       4(5) Врати, LED фарове, Лети джанти, Металик
# 119522       4(5) Врати, LED фарове, Лети джанти, Металик
# 119523  4(5) Врати, LED фарове, Лети джанти, Металик, ...
# 119524                                                NaN
#
#                               Защита       Интериор Специализирани  \
# 0               Централно заключване            NaN            NaN
# 1                                NaN  Велурен салон            NaN
# 2               Централно заключване  Велурен салон            NaN
# 3               Централно заключване  Велурен салон            NaN
# 4       Аларма, Централно заключване            NaN            NaN
# ...                              ...            ...            ...
# 119520          Централно заключване            NaN            NaN
# 119521   Каско, Централно заключване            NaN            NaN
# 119522          Централно заключване            NaN            NaN
# 119523          Централно заключване    Кожен салон            NaN
# 119524                           NaN            NaN            NaN
#
#        Област [Извън страната] Населено място [Държава] Посещения  \
# 0                        Варна             гр. Провадия       345
# 1                        Враца             гр. Козлодуй       120
# 2                        Ловеч              гр. Луковит        39
# 3                        Ловеч              гр. Луковит        27
# 4                        София                гр. София      1787
# ...                        ...                      ...       ...
# 119520                   София                гр. София      8385
# 119521          Велико Търново       гр. Велико Търново      8131
# 119522                   София                гр. София      1037
# 119523                   София                гр. София      9000
# 119524                 Пловдив              гр. Пловдив        54
#
#                                                  Заглавие
# 0                             Opel Combo 1.3cdti ПРОМОЦИЯ
# 1                             Opel Combo 1.3 M-JET 2006г.
# 2                          Opel Combo 1,6i..ТОП СЪСТОЯНИЕ
# 3                                Opel Combo ТОП СЪСТОЯНИЕ
# 4                                     Opel Combo 1.7 cdti
# ...                                                   ...
# 119520  Peugeot 308 ALLURE PACK 1,5 BlueHDi 130 EAT8 E...
# 119521  Peugeot 308 ALLURE PACK 1,5 BlueHDi 130 EAT8 E...
# 119522         Peugeot 308 GT 1,5 BlueHDi 130 EAT8 EURO 6
# 119523  Peugeot 308 GT PACK 1,6 PHEV 180 e-EAT8 от 672...
# 119524                                Peugeot 308 1.6 HDI
#
# [119525 rows x 26 columns]

# %%
# Translate column names to English for easier use
english_columns = ['Make', 'Model', 'BodyType', 'ManufactureDate', 'FuelType', 'Transmission', 'EngineSize', 'Horsepower', 'EuroStandard', 'Mileage', 'MilesPerFullCharge (EV)', 'BatteryCapacity (EV)', 'Color', 'VIN', 'Price', 'SafetyFeatures', 'ComfortFeatures', 'OtherFeatures', 'ExteriorFeatures', 'SecurityFeatures', 'InteriorFeatures', 'SpecialisedFeatures', 'Region', 'City', 'ViewCount', 'OfferTitle']

data.columns = english_columns
data
# Out:
#            Make  Model BodyType  ManufactureDate        FuelType Transmission  \
# 0          Opel  Combo    Пикап      март 2005г.         Дизелов        Ръчна
# 1          Opel  Combo    Пикап    август 2006г.         Дизелов        Ръчна
# 2          Opel  Combo    Пикап    август 2007г.        Бензинов        Ръчна
# 3          Opel  Combo    Пикап   ноември 2004г.        Бензинов        Ръчна
# 4          Opel  Combo      Ван       юни 2006г.         Дизелов        Ръчна
# ...         ...    ...      ...              ...             ...          ...
# 119520  Peugeot    308   Хечбек    август 2022г.         Дизелов  Автоматична
# 119521  Peugeot    308   Хечбек      март 2023г.         Дизелов  Автоматична
# 119522  Peugeot    308   Хечбек  февруари 2022г.         Дизелов  Автоматична
# 119523  Peugeot    308   Хечбек  декември 2022г.  Plug-in хибрид  Автоматична
# 119524  Peugeot    308   Хечбек  февруари 2008г.         Дизелов        Ръчна
#
#          EngineSize Horsepower EuroStandard    Mileage  ...  \
# 0               NaN    75 к.с.          NaN  232000 км  ...
# 1       1248 куб.см    69 к.с.       Евро 4  233013 км  ...
# 2       1600 куб.см    93 к.с.       Евро 4  193674 км  ...
# 3       1400 куб.см    90 к.с.       Евро 4  189672 км  ...
# 4       1686 куб.см   101 к.с.       Евро 4  200000 км  ...
# ...             ...        ...          ...        ...  ...
# 119520  1500 куб.см   130 к.с.       Евро 6    7174 км  ...
# 119521  1499 куб.см   130 к.с.       Евро 6    5950 км  ...
# 119522  1500 куб.см   130 к.с.       Евро 6   20600 км  ...
# 119523          NaN   180 к.с.       Евро 6   11600 км  ...
# 119524  1600 куб.см        NaN          NaN  166000 км  ...
#
#                                           ComfortFeatures  \
# 0       Датчик за светлина, Ел. Огледала, Ел. Стъкла, ...
# 1                     Регулиране на волана, Стерео уредба
# 2       Ел. Огледала, Ел. Стъкла, Ел. усилвател на вол...
# 3       Датчик за светлина, Ел. Огледала, Ел. Стъкла, ...
# 4       Ел. Огледала, Ел. Стъкла, Климатик, Мултифункц...
# ...                                                   ...
# 119520  Auto Start Stop function, Bluetooth \ handsfre...
# 119521  Auto Start Stop function, Bluetooth \ handsfre...
# 119522  Auto Start Stop function, Bluetooth \ handsfre...
# 119523  Auto Start Stop function, Bluetooth \ handsfre...
# 119524                                                NaN
#
#                                             OtherFeatures  \
# 0                                        Бартер, Нов внос
# 1             Напълно обслужен, Нов внос, Сервизна книжка
# 2                               Нов внос, Сервизна книжка
# 3             Напълно обслужен, Нов внос, Сервизна книжка
# 4                       Лизинг, Нов внос, Сервизна книжка
# ...                                                   ...
# 119520  Лизинг, Напълно обслужен, С регистрация, Серви...
# 119521                              Лизинг, С регистрация
# 119522  Лизинг, Напълно обслужен, С регистрация, Серви...
# 119523  Лизинг, Напълно обслужен, С регистрация, Серви...
# 119524                                                NaN
#
#                                          ExteriorFeatures  \
# 0                                              2(3) Врати
# 1                                     4(5) Врати, Металик
# 2                                                 Металик
# 3                             4(5) Врати, Металик, Теглич
# 4        4(5) Врати, Рейлинг на покрива, Халогенни фарове
# ...                                                   ...
# 119520  4(5) Врати, LED фарове, Лети джанти, Металик, ...
# 119521       4(5) Врати, LED фарове, Лети джанти, Металик
# 119522       4(5) Врати, LED фарове, Лети джанти, Металик
# 119523  4(5) Врати, LED фарове, Лети джанти, Металик, ...
# 119524                                                NaN
#
#                     SecurityFeatures InteriorFeatures SpecialisedFeatures  \
# 0               Централно заключване              NaN                 NaN
# 1                                NaN    Велурен салон                 NaN
# 2               Централно заключване    Велурен салон                 NaN
# 3               Централно заключване    Велурен салон                 NaN
# 4       Аларма, Централно заключване              NaN                 NaN
# ...                              ...              ...                 ...
# 119520          Централно заключване              NaN                 NaN
# 119521   Каско, Централно заключване              NaN                 NaN
# 119522          Централно заключване              NaN                 NaN
# 119523          Централно заключване      Кожен салон                 NaN
# 119524                           NaN              NaN                 NaN
#
#                 Region                City ViewCount  \
# 0                Варна        гр. Провадия       345
# 1                Враца        гр. Козлодуй       120
# 2                Ловеч         гр. Луковит        39
# 3                Ловеч         гр. Луковит        27
# 4                София           гр. София      1787
# ...                ...                 ...       ...
# 119520           София           гр. София      8385
# 119521  Велико Търново  гр. Велико Търново      8131
# 119522           София           гр. София      1037
# 119523           София           гр. София      9000
# 119524         Пловдив         гр. Пловдив        54
#
#                                                OfferTitle
# 0                             Opel Combo 1.3cdti ПРОМОЦИЯ
# 1                             Opel Combo 1.3 M-JET 2006г.
# 2                          Opel Combo 1,6i..ТОП СЪСТОЯНИЕ
# 3                                Opel Combo ТОП СЪСТОЯНИЕ
# 4                                     Opel Combo 1.7 cdti
# ...                                                   ...
# 119520  Peugeot 308 ALLURE PACK 1,5 BlueHDi 130 EAT8 E...
# 119521  Peugeot 308 ALLURE PACK 1,5 BlueHDi 130 EAT8 E...
# 119522         Peugeot 308 GT 1,5 BlueHDi 130 EAT8 EURO 6
# 119523  Peugeot 308 GT PACK 1,6 PHEV 180 e-EAT8 от 672...
# 119524                                Peugeot 308 1.6 HDI
#
# [119525 rows x 26 columns]

# %%
data.shape
# Out:
# (119525, 26)

# %%
data.dtypes
# Out:
# Make                       object
# Model                      object
# BodyType                   object
# ManufactureDate            object
# FuelType                   object
# Transmission               object
# EngineSize                 object
# Horsepower                 object
# EuroStandard               object
# Mileage                    object
# MilesPerFullCharge (EV)    object
# BatteryCapacity (EV)       object
# Color                      object
# VIN                        object
# Price                      object
# SafetyFeatures             object
# ComfortFeatures            object
# OtherFeatures              object
# ExteriorFeatures           object
# SecurityFeatures           object
# InteriorFeatures           object
# SpecialisedFeatures        object
# Region                     object
# City                       object
# ViewCount                   int64
# OfferTitle                 object
# dtype: object

# %%
numeric_columns = data.select_dtypes(include=[np.number]).columns
categorical_columns = data.select_dtypes(include=[object]).columns

numeric_columns, categorical_columns
# Out:
# (Index(['ViewCount'], dtype='object'),
#  Index(['Make', 'Model', 'BodyType', 'ManufactureDate', 'FuelType',
#         'Transmission', 'EngineSize', 'Horsepower', 'EuroStandard', 'Mileage',
#         'MilesPerFullCharge (EV)', 'BatteryCapacity (EV)', 'Color', 'VIN',
#         'Price', 'SafetyFeatures', 'ComfortFeatures', 'OtherFeatures',
#         'ExteriorFeatures', 'SecurityFeatures', 'InteriorFeatures',
#         'SpecialisedFeatures', 'Region', 'City', 'OfferTitle'],
#        dtype='object'))

# %%
# Extract month from the Year of manufacture column

extracted_months = data['ManufactureDate'].str.split().str[0]
extracted_years = data['ManufactureDate'].str.split().str[1]

month_index_dict = {
    'януари': '01',
    'февруари': '02',
    'март': '03',
    'април': '04',
    'май': '05',
    'юни': '06',
    'юли': '07',
    'август': '08',
    'септември': '09',
    'октомври': '10',
    'ноември': '11',
    'декември': '12',
}

extracted_months = extracted_months.map(lambda x: month_index_dict.get(x, np.nan))

data['ManufactureDate'] = extracted_months.str.cat(extracted_years, sep='/')

# %%
data['ManufactureDate'] = data['ManufactureDate'].str.replace('г.', '')

data['ManufactureDate']
# Out:
# 0         03/2005
# 1         08/2006
# 2         08/2007
# 3         11/2004
# 4         06/2006
#            ...
# 119520    08/2022
# 119521    03/2023
# 119522    02/2022
# 119523    12/2022
# 119524    02/2008
# Name: ManufactureDate, Length: 119525, dtype: object

# %%
data['ManufactureDate'].isna().sum()
# Out:
# np.int64(164)

# %%
data.head(20)
# Out:
#     Make  Model BodyType ManufactureDate  FuelType Transmission   EngineSize  \
# 0   Opel  Combo    Пикап         03/2005   Дизелов        Ръчна          NaN
# 1   Opel  Combo    Пикап         08/2006   Дизелов        Ръчна  1248 куб.см
# 2   Opel  Combo    Пикап         08/2007  Бензинов        Ръчна  1600 куб.см
# 3   Opel  Combo    Пикап         11/2004  Бензинов        Ръчна  1400 куб.см
# 4   Opel  Combo      Ван         06/2006   Дизелов        Ръчна  1686 куб.см
# 5   Opel  Combo    Пикап         08/2005   Дизелов        Ръчна  1700 куб.см
# 6   Opel  Combo    Пикап         06/2005   Дизелов        Ръчна  1700 куб.см
# 7   Opel  Combo      Ван         10/2009   Дизелов        Ръчна  1700 куб.см
# 8   Opel  Combo    Пикап         02/2012   Дизелов        Ръчна  1300 куб.см
# 9   Opel  Combo    Пикап         09/2010   Дизелов        Ръчна  1300 куб.см
# 10  Opel  Combo    Пикап         07/2012   Дизелов        Ръчна  1300 куб.см
# 11  Opel  Combo      Ван         07/2015   Дизелов        Ръчна  1248 куб.см
# 12  Opel  Combo    Пикап         12/2015   Дизелов        Ръчна  1300 куб.см
# 13  Opel  Combo    Пикап         01/2015   Дизелов        Ръчна  1300 куб.см
# 14  Opel  Combo    Пикап         11/2014   Дизелов        Ръчна  1300 куб.см
# 15  Opel  Combo    Пикап         09/2013   Дизелов        Ръчна  1600 куб.см
# 16  Opel  Combo  Миниван         01/2014   Дизелов        Ръчна  1600 куб.см
# 17  Opel  Combo    Пикап         04/2012   Дизелов        Ръчна  1600 куб.см
# 18  Opel  Combo    Пикап         11/2014  Бензинов        Ръчна          NaN
# 19  Opel  Combo      Ван         10/2016  Бензинов        Ръчна          NaN
#
#    Horsepower EuroStandard    Mileage  ...  \
# 0     75 к.с.          NaN  232000 км  ...
# 1     69 к.с.       Евро 4  233013 км  ...
# 2     93 к.с.       Евро 4  193674 км  ...
# 3     90 к.с.       Евро 4  189672 км  ...
# 4    101 к.с.       Евро 4  200000 км  ...
# 5    101 к.с.       Евро 4  201000 км  ...
# 6    101 к.с.       Евро 4  249000 км  ...
# 7         NaN       Евро 4  206000 км  ...
# 8     90 к.с.       Евро 5  183000 км  ...
# 9         NaN       Евро 4  211000 км  ...
# 10    90 к.с.       Евро 5  192000 км  ...
# 11    90 к.с.       Евро 5  185778 км  ...
# 12    90 к.с.       Евро 5  188203 км  ...
# 13    90 к.с.          NaN  160210 км  ...
# 14    90 к.с.       Евро 5  201111 км  ...
# 15   105 к.с.       Евро 5  180000 км  ...
# 16   105 к.с.       Евро 5  175000 км  ...
# 17   105 к.с.       Евро 5  200500 км  ...
# 18   120 к.с.       Евро 6  147000 км  ...
# 19    95 к.с.       Евро 6  109000 км  ...
#
#                                       ComfortFeatures  \
# 0   Датчик за светлина, Ел. Огледала, Ел. Стъкла, ...
# 1                 Регулиране на волана, Стерео уредба
# 2   Ел. Огледала, Ел. Стъкла, Ел. усилвател на вол...
# 3   Датчик за светлина, Ел. Огледала, Ел. Стъкла, ...
# 4   Ел. Огледала, Ел. Стъкла, Климатик, Мултифункц...
# 5   Bluetooth \ handsfree система, DVD, TV, USB, a...
# 6   Ел. Огледала, Ел. Стъкла, Климатик, Регулиране...
# 7   Бордкомпютър, Ел. Огледала, Ел. Стъкла, Климат...
# 8   Bluetooth \ handsfree система, USB, audio\vide...
# 9   Ел. Огледала, Ел. Стъкла, Климатик, Серво усил...
# 10  Бордкомпютър, Ел. Огледала, Ел. Стъкла, Климат...
# 11  Auto Start Stop function, Bluetooth \ handsfre...
# 12  Auto Start Stop function, Bluetooth \ handsfre...
# 13  USB, audio\video, IN\AUX изводи, Бордкомпютър,...
# 14  Bluetooth \ handsfree система, USB, audio\vide...
# 15  Bluetooth \ handsfree система, USB, audio\vide...
# 16  Бордкомпютър, Ел. Стъкла, Климатик, Регулиране...
# 17  USB, audio\video, IN\AUX изводи, Блокаж на диф...
# 18  Bluetooth \ handsfree система, USB, audio\vide...
# 19  USB, audio\video, IN\AUX изводи, Бордкомпютър,...
#
#                                         OtherFeatures  \
# 0                                    Бартер, Нов внос
# 1         Напълно обслужен, Нов внос, Сервизна книжка
# 2                           Нов внос, Сервизна книжка
# 3         Напълно обслужен, Нов внос, Сервизна книжка
# 4                   Лизинг, Нов внос, Сервизна книжка
# 5                Бартер, Дълга база, Лизинг, Нов внос
# 6                   Бартер, Нов внос, Сервизна книжка
# 7                           Нов внос, Сервизна книжка
# 8      Buy back, Бартер, Дълга база, Лизинг, Нов внос
# 9       Дълга база, Лизинг, Нов внос, Сервизна книжка
# 10                                           Нов внос
# 11                          Нов внос, Сервизна книжка
# 12                  Лизинг, Нов внос, Сервизна книжка
# 13                          Нов внос, Сервизна книжка
# 14                               Дълга база, Нов внос
# 15  Лизинг, Напълно обслужен, Нов внос, Сервизна к...
# 16                                           Нов внос
# 17                  Лизинг, Нов внос, Сервизна книжка
# 18       Дълга база, Метанова уредба, Сервизна книжка
# 19                          Нов внос, Сервизна книжка
#
#                                      ExteriorFeatures  \
# 0                                          2(3) Врати
# 1                                 4(5) Врати, Металик
# 2                                             Металик
# 3                         4(5) Врати, Металик, Теглич
# 4    4(5) Врати, Рейлинг на покрива, Халогенни фарове
# 5   4(5) Врати, Ксенонови фарове, Лети джанти, Мет...
# 6                                              Теглич
# 7                4(5) Врати, Теглич, Халогенни фарове
# 8       4(5) Врати, Металик, Теглич, Халогенни фарове
# 9                                          4(5) Врати
# 10                                         4(5) Врати
# 11                                 4(5) Врати, Теглич
# 12                                         4(5) Врати
# 13                        4(5) Врати, Металик, Теглич
# 14                                         4(5) Врати
# 15                                4(5) Врати, Металик
# 16                                         4(5) Врати
# 17  4(5) Врати, Лети джанти, Металик, Рейлинг на п...
# 18              4(5) Врати, Металик, Халогенни фарове
# 19                                         4(5) Врати
#
#                 SecurityFeatures InteriorFeatures SpecialisedFeatures  \
# 0           Централно заключване              NaN                 NaN
# 1                            NaN    Велурен салон                 NaN
# 2           Централно заключване    Велурен салон                 NaN
# 3           Централно заключване    Велурен салон                 NaN
# 4   Аларма, Централно заключване              NaN                 NaN
# 5   Аларма, Централно заключване              NaN                 NaN
# 6   Аларма, Централно заключване              NaN                 NaN
# 7   Аларма, Централно заключване              NaN                 NaN
# 8   Аларма, Централно заключване    Велурен салон      Хомологация N1
# 9           Централно заключване              NaN      Хомологация N1
# 10          Централно заключване              NaN      Хомологация N1
# 11  Аларма, Централно заключване              NaN                 NaN
# 12          Централно заключване              NaN      Хомологация N1
# 13  Аларма, Централно заключване              NaN                 NaN
# 14  Аларма, Централно заключване              NaN                 NaN
# 15  Аларма, Централно заключване    Велурен салон                 NaN
# 16          Централно заключване              NaN                 NaN
# 17          Централно заключване              NaN                 NaN
# 18  Аларма, Централно заключване              NaN            Хладилен
# 19          Централно заключване              NaN                 NaN
#
#             Region                City ViewCount  \
# 0            Варна        гр. Провадия       345
# 1            Враца        гр. Козлодуй       120
# 2            Ловеч         гр. Луковит        39
# 3            Ловеч         гр. Луковит        27
# 4            София           гр. София      1787
# 5   Велико Търново  гр. Велико Търново      1656
# 6            Шумен           гр. Шумен       269
# 7           Перник        с. Драгичево      2313
# 8          Пловдив         гр. Пловдив       145
# 9     Стара Загора    гр. Стара Загора       222
# 10         Пловдив         гр. Карлово       846
# 11           София           гр. София         4
# 12           София           гр. София        43
# 13          Сливен          гр. Сливен       576
# 14  Велико Търново        гр. Лясковец       295
# 15          Сливен          гр. Сливен        43
# 16         Пловдив         гр. Пловдив      7628
# 17     Благоевград          гр. Петрич         1
# 18         Дупница         гр. Дупница      1630
# 19             NaN                 NaN      5905
#
#                                            OfferTitle
# 0                         Opel Combo 1.3cdti ПРОМОЦИЯ
# 1                         Opel Combo 1.3 M-JET 2006г.
# 2                      Opel Combo 1,6i..ТОП СЪСТОЯНИЕ
# 3                            Opel Combo ТОП СЪСТОЯНИЕ
# 4                                 Opel Combo 1.7 cdti
# 5   Opel Combo 1.7CDTI 101кс 4-врати КЛИМАТИК НАВИ...
# 6                            Opel Combo 1.7CDTI КЛИМА
# 7                                  Opel Combo 1,7CDTi
# 8                            Opel Combo 1,3MJT-ЛИЗИНГ
# 9                                  Opel Combo 1.3cdti
# 10                              Opel Combo 1.3jtd E-5
# 11                        Opel Combo 1.3CDTi-HABИ.Е5В
# 12  Opel Combo N1/L1H1/2.2t/1.3CDTi/90кс/Клима/NAV...
# 13                                     Opel Combo 1.3
# 14                                 Opel Combo 1.3CDTI
# 15                            Opel Combo 1.6d-Euro-5B
# 16                                Opel Combo 1.6 CDTI
# 17           Opel Combo 1.6  KLIMATRONIK  СЕДЕМ МЕСТА
# 18                    Opel Combo 1.4i maxi-izotermico
# 19                         Opel Combo 1.4i 95кс ЕВРО6
#
# [20 rows x 26 columns]

# %%
data['FuelType'].value_counts(dropna=False)
# Out:
# FuelType
# Дизелов           66619
# Бензинов          48049
# Електрически       2246
# Хибриден           1978
# Plug-in хибрид      633
# Name: count, dtype: int64

# %%
data['Transmission'].value_counts(dropna=False)
# Out:
# Transmission
# Автоматична        67204
# Ръчна              52111
# Полуавтоматична      210
# Name: count, dtype: int64

# %%
data['EngineSize'].sample(20)
# Out:
# 34116     2000 куб.см
# 60616     3000 куб.см
# 51000     3000 куб.см
# 35262     1600 куб.см
# 39177     2000 куб.см
# 55949             NaN
# 1095              NaN
# 65958     3200 куб.см
# 66718     4663 куб.см
# 82539             NaN
# 82768     1600 куб.см
# 117266            NaN
# 58960     2000 куб.см
# 26475     2000 куб.см
# 28738             NaN
# 14        1300 куб.см
# 44960     1700 куб.см
# 84492     3500 куб.см
# 2947      2000 куб.см
# 86791     1900 куб.см
# Name: EngineSize, dtype: object

# %%
# Ensure 'EngineSize' is a string, replace ' куб.см', and convert to integer
data.loc[data['EngineSize'].notna(), 'EngineSize'] = data.loc[data['EngineSize'].notna(), 'EngineSize'].str.replace(' куб.см', '').astype('Int64')

# %%
data['EngineSize'].sample(20)
# Out:
# 110039    2000
# 41427     1400
# 32984     1600
# 21655      NaN
# 85248     2000
# 3945       NaN
# 40710      NaN
# 99869      NaN
# 109056    3600
# 21190     1800
# 34524     1200
# 77997     2300
# 94416     1998
# 108574    2200
# 58082     4000
# 99335     3200
# 21862     1250
# 83211      NaN
# 106177     NaN
# 97834      NaN
# Name: EngineSize, dtype: object

# %%
data['EngineSize'].value_counts(dropna=False)
# Out:
# EngineSize
# NaN       32678
# 2000.0    17799
# 3000.0    10669
# 1600.0     8050
# 2200.0     5008
#           ...
# 2380.0        1
# 103.0         1
# 1876.0        1
# 1374.0        1
# 4335.0        1
# Name: count, Length: 1001, dtype: int64

# %%
data.head()
# Out:
#    Make  Model BodyType ManufactureDate  FuelType Transmission EngineSize  \
# 0  Opel  Combo    Пикап         03/2005   Дизелов        Ръчна        NaN
# 1  Opel  Combo    Пикап         08/2006   Дизелов        Ръчна       1248
# 2  Opel  Combo    Пикап         08/2007  Бензинов        Ръчна       1600
# 3  Opel  Combo    Пикап         11/2004  Бензинов        Ръчна       1400
# 4  Opel  Combo      Ван         06/2006   Дизелов        Ръчна       1686
#
#   Horsepower EuroStandard    Mileage  ...  \
# 0    75 к.с.          NaN  232000 км  ...
# 1    69 к.с.       Евро 4  233013 км  ...
# 2    93 к.с.       Евро 4  193674 км  ...
# 3    90 к.с.       Евро 4  189672 км  ...
# 4   101 к.с.       Евро 4  200000 км  ...
#
#                                      ComfortFeatures  \
# 0  Датчик за светлина, Ел. Огледала, Ел. Стъкла, ...
# 1                Регулиране на волана, Стерео уредба
# 2  Ел. Огледала, Ел. Стъкла, Ел. усилвател на вол...
# 3  Датчик за светлина, Ел. Огледала, Ел. Стъкла, ...
# 4  Ел. Огледала, Ел. Стъкла, Климатик, Мултифункц...
#
#                                  OtherFeatures  \
# 0                             Бартер, Нов внос
# 1  Напълно обслужен, Нов внос, Сервизна книжка
# 2                    Нов внос, Сервизна книжка
# 3  Напълно обслужен, Нов внос, Сервизна книжка
# 4            Лизинг, Нов внос, Сервизна книжка
#
#                                    ExteriorFeatures  \
# 0                                        2(3) Врати
# 1                               4(5) Врати, Металик
# 2                                           Металик
# 3                       4(5) Врати, Металик, Теглич
# 4  4(5) Врати, Рейлинг на покрива, Халогенни фарове
#
#                SecurityFeatures InteriorFeatures SpecialisedFeatures Region  \
# 0          Централно заключване              NaN                 NaN  Варна
# 1                           NaN    Велурен салон                 NaN  Враца
# 2          Централно заключване    Велурен салон                 NaN  Ловеч
# 3          Централно заключване    Велурен салон                 NaN  Ловеч
# 4  Аларма, Централно заключване              NaN                 NaN  София
#
#            City ViewCount                      OfferTitle
# 0  гр. Провадия       345     Opel Combo 1.3cdti ПРОМОЦИЯ
# 1  гр. Козлодуй       120     Opel Combo 1.3 M-JET 2006г.
# 2   гр. Луковит        39  Opel Combo 1,6i..ТОП СЪСТОЯНИЕ
# 3   гр. Луковит        27        Opel Combo ТОП СЪСТОЯНИЕ
# 4     гр. София      1787             Opel Combo 1.7 cdti
#
# [5 rows x 26 columns]

# %%
data['Horsepower'].sample(20)
# Out:
# 87855     258 к.с.
# 36062     183 к.с.
# 13142     140 к.с.
# 56315     211 к.с.
# 77337     585 к.с.
# 60080     194 к.с.
# 30433     227 к.с.
# 71947     245 к.с.
# 57900     450 к.с.
# 82869      95 к.с.
# 73764     300 к.с.
# 10988     239 к.с.
# 47896     163 к.с.
# 38018     116 к.с.
# 85665     150 к.с.
# 9308      441 к.с.
# 104941    381 к.с.
# 93546     201 к.с.
# 93935     190 к.с.
# 5703      170 к.с.
# Name: Horsepower, dtype: object

# %%
data['Horsepower'].value_counts(dropna=False)
# Out:
# Horsepower
# 150 к.с.     6907
# NaN          6401
# 140 к.с.     4225
# 170 к.с.     3720
# 90 к.с.      3589
#              ...
# 397 к.с.        1
# 1754 к.с.       1
# 29 к.с.         1
# 32 к.с.         1
# 1390 к.с.       1
# Name: count, Length: 658, dtype: int64

# %%
data['Horsepower'] = data['Horsepower'].str.replace(' к.с.', '').astype('Int64')

data['Horsepower'].value_counts(dropna=False)
# Out:
# Horsepower
# 150     6907
# <NA>    6401
# 140     4225
# 170     3720
# 90      3589
#         ...
# 1995       1
# 736        1
# 722        1
# 464        1
# 505        1
# Name: count, Length: 658, dtype: Int64

# %%
data.head()
# Out:
#    Make  Model BodyType ManufactureDate  FuelType Transmission EngineSize  \
# 0  Opel  Combo    Пикап         03/2005   Дизелов        Ръчна        NaN
# 1  Opel  Combo    Пикап         08/2006   Дизелов        Ръчна       1248
# 2  Opel  Combo    Пикап         08/2007  Бензинов        Ръчна       1600
# 3  Opel  Combo    Пикап         11/2004  Бензинов        Ръчна       1400
# 4  Opel  Combo      Ван         06/2006   Дизелов        Ръчна       1686
#
#    Horsepower EuroStandard    Mileage  ...  \
# 0          75          NaN  232000 км  ...
# 1          69       Евро 4  233013 км  ...
# 2          93       Евро 4  193674 км  ...
# 3          90       Евро 4  189672 км  ...
# 4         101       Евро 4  200000 км  ...
#
#                                      ComfortFeatures  \
# 0  Датчик за светлина, Ел. Огледала, Ел. Стъкла, ...
# 1                Регулиране на волана, Стерео уредба
# 2  Ел. Огледала, Ел. Стъкла, Ел. усилвател на вол...
# 3  Датчик за светлина, Ел. Огледала, Ел. Стъкла, ...
# 4  Ел. Огледала, Ел. Стъкла, Климатик, Мултифункц...
#
#                                  OtherFeatures  \
# 0                             Бартер, Нов внос
# 1  Напълно обслужен, Нов внос, Сервизна книжка
# 2                    Нов внос, Сервизна книжка
# 3  Напълно обслужен, Нов внос, Сервизна книжка
# 4            Лизинг, Нов внос, Сервизна книжка
#
#                                    ExteriorFeatures  \
# 0                                        2(3) Врати
# 1                               4(5) Врати, Металик
# 2                                           Металик
# 3                       4(5) Врати, Металик, Теглич
# 4  4(5) Врати, Рейлинг на покрива, Халогенни фарове
#
#                SecurityFeatures InteriorFeatures SpecialisedFeatures Region  \
# 0          Централно заключване              NaN                 NaN  Варна
# 1                           NaN    Велурен салон                 NaN  Враца
# 2          Централно заключване    Велурен салон                 NaN  Ловеч
# 3          Централно заключване    Велурен салон                 NaN  Ловеч
# 4  Аларма, Централно заключване              NaN                 NaN  София
#
#            City ViewCount                      OfferTitle
# 0  гр. Провадия       345     Opel Combo 1.3cdti ПРОМОЦИЯ
# 1  гр. Козлодуй       120     Opel Combo 1.3 M-JET 2006г.
# 2   гр. Луковит        39  Opel Combo 1,6i..ТОП СЪСТОЯНИЕ
# 3   гр. Луковит        27        Opel Combo ТОП СЪСТОЯНИЕ
# 4     гр. София      1787             Opel Combo 1.7 cdti
#
# [5 rows x 26 columns]

# %%
data['EuroStandard'].value_counts(dropna=False)
# Out:
# EuroStandard
# Евро 6    33035
# NaN       26278
# Евро 4    25682
# Евро 5    24720
# Евро 3     7253
# Евро 2     1505
# Евро 1     1052
# Name: count, dtype: int64

# %%
data['Mileage'].sample(20)
# Out:
# 7616     266000 км
# 83956    171566 км
# 34485    234946 км
# 31603    130000 км
# 97289    280000 км
# 85340    216000 км
# 51554    227000 км
# 83095    111111 км
# 93341    272000 км
# 89656    214834 км
# 92731    178000 км
# 5340     180000 км
# 17034    168000 км
# 24623    163737 км
# 79103    213700 км
# 34025    168000 км
# 41566       100 км
# 42501    237000 км
# 8977      16800 км
# 23998    187000 км
# Name: Mileage, dtype: object

# %%
data['Mileage'].value_counts(dropna=False)
# Out:
# Mileage
# 200000 км    1819
# 220000 км    1463
# 250000 км    1435
# 230000 км    1323
# 180000 км    1314
#              ...
# 191547 км       1
# 216245 км       1
# 241234 км       1
# 149527 км       1
# 5950 км         1
# Name: count, Length: 23360, dtype: int64

# %%
data['Mileage'] = data['Mileage'].str.replace(' км', '').astype('Int64')

data['Mileage'].value_counts(dropna=False)
# Out:
# Mileage
# 200000    1819
# 220000    1463
# 250000    1435
# 230000    1323
# 180000    1314
#           ...
# 29267        1
# 56868        1
# 129744       1
# 91415        1
# 138943       1
# Name: count, Length: 23360, dtype: Int64

# %%
data.head()
# Out:
#    Make  Model BodyType ManufactureDate  FuelType Transmission EngineSize  \
# 0  Opel  Combo    Пикап         03/2005   Дизелов        Ръчна        NaN
# 1  Opel  Combo    Пикап         08/2006   Дизелов        Ръчна       1248
# 2  Opel  Combo    Пикап         08/2007  Бензинов        Ръчна       1600
# 3  Opel  Combo    Пикап         11/2004  Бензинов        Ръчна       1400
# 4  Opel  Combo      Ван         06/2006   Дизелов        Ръчна       1686
#
#    Horsepower EuroStandard  Mileage  ...  \
# 0          75          NaN   232000  ...
# 1          69       Евро 4   233013  ...
# 2          93       Евро 4   193674  ...
# 3          90       Евро 4   189672  ...
# 4         101       Евро 4   200000  ...
#
#                                      ComfortFeatures  \
# 0  Датчик за светлина, Ел. Огледала, Ел. Стъкла, ...
# 1                Регулиране на волана, Стерео уредба
# 2  Ел. Огледала, Ел. Стъкла, Ел. усилвател на вол...
# 3  Датчик за светлина, Ел. Огледала, Ел. Стъкла, ...
# 4  Ел. Огледала, Ел. Стъкла, Климатик, Мултифункц...
#
#                                  OtherFeatures  \
# 0                             Бартер, Нов внос
# 1  Напълно обслужен, Нов внос, Сервизна книжка
# 2                    Нов внос, Сервизна книжка
# 3  Напълно обслужен, Нов внос, Сервизна книжка
# 4            Лизинг, Нов внос, Сервизна книжка
#
#                                    ExteriorFeatures  \
# 0                                        2(3) Врати
# 1                               4(5) Врати, Металик
# 2                                           Металик
# 3                       4(5) Врати, Металик, Теглич
# 4  4(5) Врати, Рейлинг на покрива, Халогенни фарове
#
#                SecurityFeatures InteriorFeatures SpecialisedFeatures Region  \
# 0          Централно заключване              NaN                 NaN  Варна
# 1                           NaN    Велурен салон                 NaN  Враца
# 2          Централно заключване    Велурен салон                 NaN  Ловеч
# 3          Централно заключване    Велурен салон                 NaN  Ловеч
# 4  Аларма, Централно заключване              NaN                 NaN  София
#
#            City ViewCount                      OfferTitle
# 0  гр. Провадия       345     Opel Combo 1.3cdti ПРОМОЦИЯ
# 1  гр. Козлодуй       120     Opel Combo 1.3 M-JET 2006г.
# 2   гр. Луковит        39  Opel Combo 1,6i..ТОП СЪСТОЯНИЕ
# 3   гр. Луковит        27        Opel Combo ТОП СЪСТОЯНИЕ
# 4     гр. София      1787             Opel Combo 1.7 cdti
#
# [5 rows x 26 columns]

# %%
numeric_columns = data.select_dtypes(include=[np.number]).columns

numeric_columns
# Out:
# Index(['Horsepower', 'Mileage', 'ViewCount'], dtype='object')

# %%
data['MilesPerFullCharge (EV)'].value_counts(dropna=False)
# Out:
# MilesPerFullCharge (EV)
# NaN        116663
# 300 км.       113
# 450 км.       106
# 50 км.         93
# 500 км.        93
#             ...
# 479 км.         1
# 579 км.         1
# 639 км.         1
# 518 км.         1
# 66 км.          1
# Name: count, Length: 367, dtype: int64

# %%
data[data['MilesPerFullCharge (EV)'].notna()].sample(20)
# Out:
#                  Make      Model BodyType ManufactureDate        FuelType  \
# 40735           Tesla    Model 3    Седан         03/2021    Електрически
# 96986           Tesla    Model X     Джип         11/2017    Електрически
# 86227           Tesla    Model S    Седан         01/2023    Електрически
# 63085         Peugeot        208   Хечбек         06/2021    Електрически
# 12813              VW       ID.3   Хечбек         10/2020    Електрически
# 82042           Volvo       XC40     Джип         11/2022  Plug-in хибрид
# 106588         Nissan       Leaf   Хечбек         03/2019    Електрически
# 40710           Tesla    Model 3    Седан         12/2021    Електрически
# 64785         Renault     Megane   Хечбек         08/2023    Електрически
# 71679         Renault        Zoe   Хечбек         10/2018    Електрически
# 98847             BMW         i3   Хечбек         11/2020    Електрически
# 98690             BMW         i3   Хечбек         02/2017    Електрически
# 105057            BMW         X5     Джип         10/2016  Plug-in хибрид
# 71157             BMW         iX     Джип         07/2021    Електрически
# 96977           Tesla    Model X    Седан         10/2018    Електрически
# 53360         Peugeot       2008     Джип         09/2021    Електрически
# 1666    Mercedes-Benz        EQA     Джип         03/2023    Електрически
# 64887   Mercedes-Benz        EQE     Джип         12/2023    Електрически
# 13496      Mitsubishi     I-MiEV   Хечбек         09/2015    Електрически
# 83144      Mitsubishi  Outlander     Джип         12/2018  Plug-in хибрид
#
#        Transmission EngineSize  Horsepower EuroStandard  Mileage  ...  \
# 40735   Автоматична        NaN         325       Евро 6    55610  ...
# 96986   Автоматична        NaN         525       Евро 6   110600  ...
# 86227   Автоматична        NaN         670       Евро 6        7  ...
# 63085   Автоматична        NaN         136       Евро 6    18358  ...
# 12813   Автоматична        NaN         204       Евро 6    34164  ...
# 82042   Автоматична        NaN         261       Евро 6    11000  ...
# 106588  Автоматична        NaN         150       Евро 6    89126  ...
# 40710   Автоматична        NaN         320       Евро 6    52000  ...
# 64785   Автоматична        NaN         220       Евро 6       10  ...
# 71679   Автоматична        NaN          92          NaN    85000  ...
# 98847   Автоматична        NaN         184       Евро 6    18000  ...
# 98690   Автоматична        NaN         170       Евро 6    32000  ...
# 105057  Автоматична        NaN         313       Евро 6   180000  ...
# 71157   Автоматична        NaN         523       Евро 6     8500  ...
# 96977   Автоматична        NaN         334          NaN    41000  ...
# 53360   Автоматична        NaN         136          NaN    15800  ...
# 1666    Автоматична        NaN         292          NaN     5000  ...
# 64887   Автоматична        NaN         292       Евро 6    18000  ...
# 13496   Автоматична        NaN          67       Евро 6    31000  ...
# 83144   Автоматична        NaN         118       Евро 6    54910  ...
#
#                                           ComfortFeatures  \
# 40735                                                 NaN
# 96986   Bluetooth \ handsfree система, DVD, TV, USB, a...
# 86227   Bluetooth \ handsfree система, Безключово пале...
# 63085   Auto Start Stop function, Bluetooth \ handsfre...
# 12813   Auto Start Stop function, Bluetooth \ handsfre...
# 82042   Auto Start Stop function, Bluetooth \ handsfre...
# 106588  Bluetooth \ handsfree система, DVD, TV, Steptr...
# 40710   Bluetooth \ handsfree система, USB, audio\vide...
# 64785   Auto Start Stop function, Bluetooth \ handsfre...
# 71679   Auto Start Stop function, Bluetooth \ handsfre...
# 98847   Auto Start Stop function, Bluetooth \ handsfre...
# 98690   Auto Start Stop function, Bluetooth \ handsfre...
# 105057  Auto Start Stop function, Bluetooth \ handsfre...
# 71157   Auto Start Stop function, Bluetooth \ handsfre...
# 96977   Bluetooth \ handsfree система, DVD, TV, USB, a...
# 53360   Bluetooth \ handsfree система, USB, audio\vide...
# 1666    Bluetooth \ handsfree система, USB, audio\vide...
# 64887   Bluetooth \ handsfree система, USB, audio\vide...
# 13496   Bluetooth \ handsfree система, USB, audio\vide...
# 83144   Bluetooth \ handsfree система, Steptronic, Tip...
#
#                                             OtherFeatures  \
# 40735                                                 NaN
# 96986   4x4, 7 места, Дълга база, Напълно обслужен, С ...
# 86227   4x4, Бартер, Лизинг, Напълно обслужен, Нов вно...
# 63085                  Лизинг, Напълно обслужен, Нов внос
# 12813                                    Лизинг, Нов внос
# 82042   4x4, Buy back, Лизинг, Нов внос, Сервизна книж...
# 106588  Buy back, Капариран\Продаден, Лизинг, Нов внос...
# 40710                                       С регистрация
# 64785   Лизинг, Напълно обслужен, С регистрация, Серви...
# 71679                               Лизинг, С регистрация
# 98847    Напълно обслужен, С регистрация, Сервизна книжка
# 98690                           Нов внос, Сервизна книжка
# 105057     4x4, Напълно обслужен, Нов внос, С регистрация
# 71157                            Лизинг, Напълно обслужен
# 96977                  4x4, Бартер, Лизинг, С регистрация
# 53360    Buy back, Лизинг, С регистрация, Сервизна книжка
# 1666    4x4, Buy back, Лизинг, Нов внос, Сервизна книж...
# 64887   4x4, Лизинг, Напълно обслужен, С регистрация, ...
# 13496    Напълно обслужен, С регистрация, Сервизна книжка
# 83144                4x4, Напълно обслужен, С регистрация
#
#                                          ExteriorFeatures  \
# 40735                                                 NaN
# 96986   4(5) Врати, LED фарове, Ксенонови фарове, Лети...
# 86227   4(5) Врати, LED фарове, Ксенонови фарове, Лети...
# 63085   4(5) Врати, LED фарове, Ксенонови фарове, Лети...
# 12813   4(5) Врати, LED фарове, Ксенонови фарове, Лети...
# 82042   4(5) Врати, LED фарове, Лети джанти, Металик, ...
# 106588  4(5) Врати, LED фарове, Ксенонови фарове, Лети...
# 40710   4(5) Врати, LED фарове, Лети джанти, Металик, ...
# 64785   4(5) Врати, LED фарове, Лети джанти, Металик, ...
# 71679               4(5) Врати, Металик, Халогенни фарове
# 98847                 4(5) Врати, LED фарове, Лети джанти
# 98690   4(5) Врати, LED фарове, Лети джанти, Металик, ...
# 105057  4(5) Врати, Ксенонови фарове, Лети джанти, Мет...
# 71157   4(5) Врати, LED фарове, Лети джанти, Металик, ...
# 96977   4(5) Врати, LED фарове, Ксенонови фарове, Лети...
# 53360   4(5) Врати, LED фарове, Лети джанти, Металик, ...
# 1666    4(5) Врати, LED фарове, Лети джанти, Металик, ...
# 64887                 4(5) Врати, LED фарове, Лети джанти
# 13496   4(5) Врати, LED фарове, Лети джанти, Халогенни...
# 83144   4(5) Врати, LED фарове, Лети джанти, Металик, ...
#
#                     SecurityFeatures InteriorFeatures SpecialisedFeatures  \
# 40735                            NaN              NaN                 NaN
# 96986   Аларма, Централно заключване      Кожен салон                 NaN
# 86227   Аларма, Централно заключване      Кожен салон                 NaN
# 63085   Аларма, Централно заключване              NaN                 NaN
# 12813   Аларма, Централно заключване              NaN                 NaN
# 82042   Аларма, Централно заключване      Кожен салон                 NaN
# 106588  Аларма, Централно заключване    Велурен салон                 NaN
# 40710    Каско, Централно заключване      Кожен салон                 NaN
# 64785    Каско, Централно заключване              NaN                 NaN
# 71679   Аларма, Централно заключване              NaN                 NaN
# 98847           Централно заключване      Кожен салон                 NaN
# 98690   Аларма, Централно заключване              NaN                 NaN
# 105057                        Аларма              NaN                 NaN
# 71157   Аларма, Централно заключване      Кожен салон                 NaN
# 96977           Централно заключване      Кожен салон                 NaN
# 53360           Централно заключване              NaN                 NaN
# 1666    Аларма, Централно заключване      Кожен салон                 NaN
# 64887   Аларма, Централно заключване              NaN                 NaN
# 13496   Аларма, Централно заключване              NaN                 NaN
# 83144   Аларма, Централно заключване      Кожен салон                 NaN
#
#               Region              City ViewCount  \
# 40735          София         гр. София       611
# 96986          София         гр. София      2896
# 86227          София         гр. София     10033
# 63085          София         гр. София       167
# 12813          София         гр. София       360
# 82042          София         гр. София      1136
# 106588         София         гр. София       315
# 40710          София         гр. София      2877
# 64785          София         гр. София      6777
# 71679   Стара Загора  гр. Стара Загора       327
# 98847    Благоевград   гр. Благоевград       586
# 98690          София         гр. София        47
# 105057         София         гр. София        93
# 71157          София         гр. София       417
# 96977          Варна         гр. Варна      7409
# 53360          Варна         гр. Варна       449
# 1666           София         гр. София      1327
# 64887          София         гр. София       372
# 13496          София         гр. София       155
# 83144          София         гр. София       229
#
#                                                OfferTitle
# 40735                                   Tesla Model 3 SR+
# 96986          Tesla Model X 75D FREE Supercharging 525hp
# 86227             Tesla Model S 7km/Long Range AWD /670ps
# 63085                   Peugeot 208 GT/FULL LED/PANO/NAVI
# 12813                           VW ID.3 34164 км / 204 кс
# 82042   Volvo XC40 T5 Recharge =Ultimate Dark= Panoram...
# 106588                    Nissan Leaf  12.2018/Tekna/40KW
# 40710                   Tesla Model 3 Standard Range Plus
# 64785   Renault Megane 9999лв за получаване, iconic EV...
# 71679                  Renault Zoe 41KW собствена батерия
# 98847             BMW i3 i3S, 120Ah, Термопомпа, LED, NAV
# 98690      BMW i3 32000км 94ah 33.2kw Термопомпа Гаранция
# 105057           BMW X5 40e M-pack, ACC, HUD, 360  камери
# 71157                                   BMW iX  xDrive 50
# 96977                                   Tesla Model X 75D
# 53360        Peugeot 2008 ALLURE Electric 100 кВ 136 к.с.
# 1666    Mercedes-Benz EQA 350 4Matic =AMG Line= Night ...
# 64887                    Mercedes-Benz EQE 350 4MATIC SUV
# 13496                           Mitsubishi I-MiEV 16 KW h
# 83144                 Mitsubishi Outlander OUTLANDER PHEV
#
# [20 rows x 26 columns]

# %%
data['MilesPerFullCharge (EV)'] = data['MilesPerFullCharge (EV)'].str.replace(' км', '').astype('Float64')

data['MilesPerFullCharge (EV)'].value_counts(dropna=False)
# Out:
# MilesPerFullCharge (EV)
# <NA>     116663
# 300.0       113
# 450.0       106
# 50.0         93
# 500.0        93
#           ...
# 453.0         1
# 479.0         1
# 579.0         1
# 639.0         1
# 232.0         1
# Name: count, Length: 367, dtype: Int64

# %%
numeric_columns = data.select_dtypes(include=[np.number]).columns
numeric_columns
# Out:
# Index(['Horsepower', 'Mileage', 'MilesPerFullCharge (EV)', 'ViewCount'], dtype='object')

# %%
data['BatteryCapacity (EV)'].value_counts(dropna=False)
# Out:
# BatteryCapacity (EV)
# NaN         116663
# 82 kWh         103
# 100 kWh        101
# 50 kWh          91
# 64 kWh          80
#              ...
# 25.6 kWh         1
# 23.6 kWh         1
# 61.3 kWh         1
# 26.6 kWh         1
# 3.5 kWh          1
# Name: count, Length: 273, dtype: int64

# %%
data['BatteryCapacity (EV)'] = data['BatteryCapacity (EV)'].str.replace(' kWh', '').astype('Float64')

# %%
data['BatteryCapacity (EV)'].value_counts(dropna=False)
# Out:
# BatteryCapacity (EV)
# <NA>     116663
# 82.0        103
# 100.0       101
# 50.0         91
# 64.0         80
#           ...
# 62.2          1
# 10.2          1
# 18.5          1
# 73.4          1
# 78.4          1
# Name: count, Length: 273, dtype: Int64

# %%
data['Color'].value_counts(dropna=False)
# Out:
# Color
# Черен             32330
# Сив               18361
# Бял               15592
# Тъмно сив          8220
# NaN                6113
# Светло сив         5927
# Син                4917
# Тъмно син мет.     3565
# Червен             3155
# Tъмно син          2989
# Металик            2573
# Графит             2546
# Сребърен           2050
# Зелен              1533
# Кафяв              1425
# Светло син         1154
# Бордо              1046
# Жълт               1016
# Перла               833
# Бежов               753
# Златист             642
# Т.зелен             590
# Хамелеон            380
# Оранжев             370
# Бронз               270
# Пясъчен             223
# Лилав               188
# Тъмно червен        110
# Виолетов            101
# Вишнев               80
# Резидав              68
# Сахара               67
# Керемиден            66
# Слонова кост         59
# Кремав               47
# Винен                44
# Пепеляв              37
# Тютюн                32
# Банан                19
# Розов                17
# Охра                 16
# Беата                 1
# Name: count, dtype: int64

# %%
data['VIN'].value_counts(dropna=False)
# Out:
# VIN
# NaN                  107461
# WDD2040231A645914         4
# WDD2130231A735709         4
# W0VBD8EG8H8102716         4
# WDD2043021G357818         4
#                       ...
# W0LBD8EK8G8092376         1
# W0LBF6EA5GG102566         1
# W0VBF8EU9L8010877         1
# W0LBD6EK1GG109769         1
# VR3FBYHZTNY548261         1
# Name: count, Length: 10034, dtype: int64

# %%
data.head()
# Out:
#    Make  Model BodyType ManufactureDate  FuelType Transmission EngineSize  \
# 0  Opel  Combo    Пикап         03/2005   Дизелов        Ръчна        NaN
# 1  Opel  Combo    Пикап         08/2006   Дизелов        Ръчна       1248
# 2  Opel  Combo    Пикап         08/2007  Бензинов        Ръчна       1600
# 3  Opel  Combo    Пикап         11/2004  Бензинов        Ръчна       1400
# 4  Opel  Combo      Ван         06/2006   Дизелов        Ръчна       1686
#
#    Horsepower EuroStandard  Mileage  ...  \
# 0          75          NaN   232000  ...
# 1          69       Евро 4   233013  ...
# 2          93       Евро 4   193674  ...
# 3          90       Евро 4   189672  ...
# 4         101       Евро 4   200000  ...
#
#                                      ComfortFeatures  \
# 0  Датчик за светлина, Ел. Огледала, Ел. Стъкла, ...
# 1                Регулиране на волана, Стерео уредба
# 2  Ел. Огледала, Ел. Стъкла, Ел. усилвател на вол...
# 3  Датчик за светлина, Ел. Огледала, Ел. Стъкла, ...
# 4  Ел. Огледала, Ел. Стъкла, Климатик, Мултифункц...
#
#                                  OtherFeatures  \
# 0                             Бартер, Нов внос
# 1  Напълно обслужен, Нов внос, Сервизна книжка
# 2                    Нов внос, Сервизна книжка
# 3  Напълно обслужен, Нов внос, Сервизна книжка
# 4            Лизинг, Нов внос, Сервизна книжка
#
#                                    ExteriorFeatures  \
# 0                                        2(3) Врати
# 1                               4(5) Врати, Металик
# 2                                           Металик
# 3                       4(5) Врати, Металик, Теглич
# 4  4(5) Врати, Рейлинг на покрива, Халогенни фарове
#
#                SecurityFeatures InteriorFeatures SpecialisedFeatures Region  \
# 0          Централно заключване              NaN                 NaN  Варна
# 1                           NaN    Велурен салон                 NaN  Враца
# 2          Централно заключване    Велурен салон                 NaN  Ловеч
# 3          Централно заключване    Велурен салон                 NaN  Ловеч
# 4  Аларма, Централно заключване              NaN                 NaN  София
#
#            City ViewCount                      OfferTitle
# 0  гр. Провадия       345     Opel Combo 1.3cdti ПРОМОЦИЯ
# 1  гр. Козлодуй       120     Opel Combo 1.3 M-JET 2006г.
# 2   гр. Луковит        39  Opel Combo 1,6i..ТОП СЪСТОЯНИЕ
# 3   гр. Луковит        27        Opel Combo ТОП СЪСТОЯНИЕ
# 4     гр. София      1787             Opel Combo 1.7 cdti
#
# [5 rows x 26 columns]

# %%
data['Price'].sample(20)
# Out:
# 35493       6 300 лв.
# 15503       9 900 лв.
# 13390      12 200 лв.
# 66200      66 666 лв.
# 43650      31 800 лв.
# 13419      13 300 лв.
# 39177      17 900 лв.
# 116747      9 000 лв.
# 63189      37 500 лв.
# 107292     18 100 лв.
# 103727      8 600 лв.
# 107532      5 999 лв.
# 22618     144 900 лв.
# 49439      10 000 лв.
# 119272     14 000 лв.
# 73966      21 800 лв.
# 71612      34 800 лв.
# 4829       39 900 лв.
# 27889      53 900 лв.
# 109848     93 900 лв.
# Name: Price, dtype: object

# %%
data['Price'].value_counts()
# Out:
# Price
# 6 500 лв.        1021
# При запитване    1014
# 5 500 лв.         933
# 8 500 лв.         920
# 7 500 лв.         889
#                  ...
# 120 825 лв.         1
# 122 733 лв.         1
# 147 381 лв.         1
# 128 590 лв.         1
# 22 295 лв.          1
# Name: count, Length: 7017, dtype: int64

# %%
price_in_eur = data['Price'].str.contains('EUR')
valid_price_rows = ~data['Price'].str.contains('При запитване')

data.loc[valid_price_rows, 'Price'] = data.loc[valid_price_rows, 'Price'].str.replace(' лв.', '').str.replace(' EUR', '').str.replace(' ', '')

# Convert EUR prices to BGN
eur_bgn_exchange_rate = 1.95583
data.loc[price_in_eur, 'Price'] = (data.loc[price_in_eur, 'Price'].astype('float') * eur_bgn_exchange_rate).astype(object)

data['Price'].sample(20)
# Out:
# 88565      29900
# 31397      15555
# 60616      12000
# 19954      25600
# 79850      27600
# 104031     20900
# 117728     23500
# 118304     12300
# 82347     406900
# 86472       7499
# 10030      24890
# 84765       8800
# 68841      34999
# 9732        4700
# 3219       13600
# 69434       3650
# 67163       8700
# 50497      88500
# 16316       6300
# 107285     13990
# Name: Price, dtype: object

# %%
data['Price'].value_counts(dropna=False)
# Out:
# Price
# 6500             1021
# При запитване    1014
# 5500              933
# 8500              920
# 7500              889
#                  ...
# 120825              1
# 122733              1
# 147381              1
# 128590              1
# 22295               1
# Name: count, Length: 7017, dtype: int64

# %%
data['Price'].sample(20)
# Out:
# 118502         7990
# 43880          8350
# 85567         14500
# 75030         25000
# 66797        104900
# 24865         99099
# 20127         13999
# 116227    146687.25
# 107946        49000
# 30397          3690
# 53340         52999
# 9101          11900
# 48953          8000
# 91115         16500
# 32358         10000
# 12852         68600
# 34010         11900
# 83549         22499
# 110446         7299
# 64099         89900
# Name: Price, dtype: object

# %%
data.head()
# Out:
#    Make  Model BodyType ManufactureDate  FuelType Transmission EngineSize  \
# 0  Opel  Combo    Пикап         03/2005   Дизелов        Ръчна        NaN
# 1  Opel  Combo    Пикап         08/2006   Дизелов        Ръчна       1248
# 2  Opel  Combo    Пикап         08/2007  Бензинов        Ръчна       1600
# 3  Opel  Combo    Пикап         11/2004  Бензинов        Ръчна       1400
# 4  Opel  Combo      Ван         06/2006   Дизелов        Ръчна       1686
#
#    Horsepower EuroStandard  Mileage  ...  \
# 0          75          NaN   232000  ...
# 1          69       Евро 4   233013  ...
# 2          93       Евро 4   193674  ...
# 3          90       Евро 4   189672  ...
# 4         101       Евро 4   200000  ...
#
#                                      ComfortFeatures  \
# 0  Датчик за светлина, Ел. Огледала, Ел. Стъкла, ...
# 1                Регулиране на волана, Стерео уредба
# 2  Ел. Огледала, Ел. Стъкла, Ел. усилвател на вол...
# 3  Датчик за светлина, Ел. Огледала, Ел. Стъкла, ...
# 4  Ел. Огледала, Ел. Стъкла, Климатик, Мултифункц...
#
#                                  OtherFeatures  \
# 0                             Бартер, Нов внос
# 1  Напълно обслужен, Нов внос, Сервизна книжка
# 2                    Нов внос, Сервизна книжка
# 3  Напълно обслужен, Нов внос, Сервизна книжка
# 4            Лизинг, Нов внос, Сервизна книжка
#
#                                    ExteriorFeatures  \
# 0                                        2(3) Врати
# 1                               4(5) Врати, Металик
# 2                                           Металик
# 3                       4(5) Врати, Металик, Теглич
# 4  4(5) Врати, Рейлинг на покрива, Халогенни фарове
#
#                SecurityFeatures InteriorFeatures SpecialisedFeatures Region  \
# 0          Централно заключване              NaN                 NaN  Варна
# 1                           NaN    Велурен салон                 NaN  Враца
# 2          Централно заключване    Велурен салон                 NaN  Ловеч
# 3          Централно заключване    Велурен салон                 NaN  Ловеч
# 4  Аларма, Централно заключване              NaN                 NaN  София
#
#            City ViewCount                      OfferTitle
# 0  гр. Провадия       345     Opel Combo 1.3cdti ПРОМОЦИЯ
# 1  гр. Козлодуй       120     Opel Combo 1.3 M-JET 2006г.
# 2   гр. Луковит        39  Opel Combo 1,6i..ТОП СЪСТОЯНИЕ
# 3   гр. Луковит        27        Opel Combo ТОП СЪСТОЯНИЕ
# 4     гр. София      1787             Opel Combo 1.7 cdti
#
# [5 rows x 26 columns]

# %%
numeric_columns = data.select_dtypes(include=[np.number]).columns
categorical_columns = data.select_dtypes(include=[object]).columns

numeric_columns, categorical_columns
# Out:
# (Index(['Horsepower', 'Mileage', 'MilesPerFullCharge (EV)',
#         'BatteryCapacity (EV)', 'ViewCount'],
#        dtype='object'),
#  Index(['Make', 'Model', 'BodyType', 'ManufactureDate', 'FuelType',
#         'Transmission', 'EngineSize', 'EuroStandard', 'Color', 'VIN', 'Price',
#         'SafetyFeatures', 'ComfortFeatures', 'OtherFeatures',
#         'ExteriorFeatures', 'SecurityFeatures', 'InteriorFeatures',
#         'SpecialisedFeatures', 'Region', 'City', 'OfferTitle'],
#        dtype='object'))

# %%
data['Region'].value_counts(dropna=False)
# Out:
# Region
# София             43008
# Пловдив           14298
# Варна              7040
# Стара Загора       4839
# Бургас             4715
# Враца              4451
# Благоевград        3832
# Пазарджик          3708
# Хасково            3451
# Плевен             3382
# Русе               3016
# Велико Търново     2986
# Дупница            2920
# Сливен             2741
# Перник             2442
# Шумен              1776
# Габрово            1547
# Кюстендил          1187
# Ловеч              1174
# Монтана            1088
# Кърджали            965
# Добрич              826
# Ямбол               717
# Търговище           706
# Смолян              616
# Разград             607
# Извън страната      555
# Видин               475
# Силистра            455
# NaN                   2
# Name: count, dtype: int64

# %%
data['City'].value_counts(dropna=False)
# Out:
# City
# гр. София           39716
# гр. Пловдив          9609
# гр. Варна            6616
# гр. Бургас           3618
# гр. Враца            3600
#                     ...
# с. Долно Камарци        1
# Сърбия                  1
# с. Драгоево             1
# с. Беслен               1
# с. Новоселец            1
# Name: count, Length: 1036, dtype: int64

# %%
numeric_columns = data.select_dtypes(include=[np.number]).columns
categorical_columns = data.select_dtypes(include=[object]).columns

numeric_columns, categorical_columns
# Out:
# (Index(['Horsepower', 'Mileage', 'MilesPerFullCharge (EV)',
#         'BatteryCapacity (EV)', 'ViewCount'],
#        dtype='object'),
#  Index(['Make', 'Model', 'BodyType', 'ManufactureDate', 'FuelType',
#         'Transmission', 'EngineSize', 'EuroStandard', 'Color', 'VIN', 'Price',
#         'SafetyFeatures', 'ComfortFeatures', 'OtherFeatures',
#         'ExteriorFeatures', 'SecurityFeatures', 'InteriorFeatures',
#         'SpecialisedFeatures', 'Region', 'City', 'OfferTitle'],
#        dtype='object'))

# %%
data['BodyType'].value_counts(dropna=False)
# Out:
# BodyType
# Джип              29098
# Седан             25528
# Хечбек            23681
# Комби             21399
# Купе               6127
# Ван                4569
# Стреч лимузина     2900
# Миниван            2483
# Пикап              2199
# Кабрио             1540
# Линейка               1
# Name: count, dtype: int64

# %%
data.tail()
# Out:
#            Make Model BodyType ManufactureDate        FuelType Transmission  \
# 119520  Peugeot   308   Хечбек         08/2022         Дизелов  Автоматична
# 119521  Peugeot   308   Хечбек         03/2023         Дизелов  Автоматична
# 119522  Peugeot   308   Хечбек         02/2022         Дизелов  Автоматична
# 119523  Peugeot   308   Хечбек         12/2022  Plug-in хибрид  Автоматична
# 119524  Peugeot   308   Хечбек         02/2008         Дизелов        Ръчна
#
#        EngineSize  Horsepower EuroStandard  Mileage  ...  \
# 119520       1500         130       Евро 6     7174  ...
# 119521       1499         130       Евро 6     5950  ...
# 119522       1500         130       Евро 6    20600  ...
# 119523        NaN         180       Евро 6    11600  ...
# 119524       1600        <NA>          NaN   166000  ...
#
#                                           ComfortFeatures  \
# 119520  Auto Start Stop function, Bluetooth \ handsfre...
# 119521  Auto Start Stop function, Bluetooth \ handsfre...
# 119522  Auto Start Stop function, Bluetooth \ handsfre...
# 119523  Auto Start Stop function, Bluetooth \ handsfre...
# 119524                                                NaN
#
#                                             OtherFeatures  \
# 119520  Лизинг, Напълно обслужен, С регистрация, Серви...
# 119521                              Лизинг, С регистрация
# 119522  Лизинг, Напълно обслужен, С регистрация, Серви...
# 119523  Лизинг, Напълно обслужен, С регистрация, Серви...
# 119524                                                NaN
#
#                                          ExteriorFeatures  \
# 119520  4(5) Врати, LED фарове, Лети джанти, Металик, ...
# 119521       4(5) Врати, LED фарове, Лети джанти, Металик
# 119522       4(5) Врати, LED фарове, Лети джанти, Металик
# 119523  4(5) Врати, LED фарове, Лети джанти, Металик, ...
# 119524                                                NaN
#
#                    SecurityFeatures InteriorFeatures SpecialisedFeatures  \
# 119520         Централно заключване              NaN                 NaN
# 119521  Каско, Централно заключване              NaN                 NaN
# 119522         Централно заключване              NaN                 NaN
# 119523         Централно заключване      Кожен салон                 NaN
# 119524                          NaN              NaN                 NaN
#
#                 Region                City ViewCount  \
# 119520           София           гр. София      8385
# 119521  Велико Търново  гр. Велико Търново      8131
# 119522           София           гр. София      1037
# 119523           София           гр. София      9000
# 119524         Пловдив         гр. Пловдив        54
#
#                                                OfferTitle
# 119520  Peugeot 308 ALLURE PACK 1,5 BlueHDi 130 EAT8 E...
# 119521  Peugeot 308 ALLURE PACK 1,5 BlueHDi 130 EAT8 E...
# 119522         Peugeot 308 GT 1,5 BlueHDi 130 EAT8 EURO 6
# 119523  Peugeot 308 GT PACK 1,6 PHEV 180 e-EAT8 от 672...
# 119524                                Peugeot 308 1.6 HDI
#
# [5 rows x 26 columns]

# %%
# Handle duplicated rows

# Exclude the columns which are not relevant for the comparison
# Some offers are listed 2 TIMES - under grouped models (like BMW 3 Series, 5 Series, etc.) AND also under the specific model in the group (like BMW 320, 520, etc.)

# Let's check by VIN number for example as it should be unique for each vehicle
duplicate_vin_rows = data[data.duplicated(subset=['VIN'], keep=False)].dropna(subset=['VIN'])

duplicate_vin_rows.sort_values(by='VIN')
# Out:
#                  Make              Model        BodyType ManufactureDate  \
# 58549             BMW               530E           Седан         04/2022
# 50549             BMW            5-серия           Седан         04/2022
# 65551   Mercedes-Benz            S-класа  Стреч лимузина         05/2018
# 58827   Mercedes-Benz              S 450  Стреч лимузина         05/2018
# 40149             BMW            3-серия           Седан         01/2021
# ...               ...                ...             ...             ...
# 77725           Volvo               Xc90            Джип         10/2011
# 90478           Volvo                V40          Хечбек         12/2016
# 117945          Volvo  V40 Cross Country          Хечбек         05/2016
# 118090           Fiat                500          Хечбек         12/2018
# 111729         Abarth                595          Хечбек         12/2018
#
#               FuelType Transmission EngineSize  Horsepower EuroStandard  \
# 58549   Plug-in хибрид  Автоматична        NaN         293       Евро 6
# 50549   Plug-in хибрид  Автоматична        NaN         293       Евро 6
# 65551         Бензинов  Автоматична       3000         370       Евро 5
# 58827         Бензинов  Автоматична       3000         370       Евро 5
# 40149         Бензинов  Автоматична        NaN         258       Евро 5
# ...                ...          ...        ...         ...          ...
# 77725          Дизелов  Автоматична       2400        <NA>       Евро 5
# 90478          Дизелов  Автоматична       2000         150       Евро 5
# 117945         Дизелов  Автоматична       2000         150       Евро 5
# 118090        Бензинов        Ръчна       1400         145       Евро 6
# 111729        Бензинов        Ръчна       1400         145       Евро 6
#
#         Mileage  ...                                    ComfortFeatures  \
# 58549     17800  ...  Auto Start Stop function, Bluetooth \ handsfre...
# 50549     17800  ...  Auto Start Stop function, Bluetooth \ handsfre...
# 65551     89000  ...                                                NaN
# 58827     89000  ...                                                NaN
# 40149     52000  ...  Auto Start Stop function, Бордкомпютър, Мултиф...
# ...         ...  ...                                                ...
# 77725    244576  ...  Bluetooth \ handsfree система, Steptronic, Tip...
# 90478    187000  ...  Bluetooth \ handsfree система, Steptronic, Tip...
# 117945   187000  ...  Bluetooth \ handsfree система, DVD, TV, USB, a...
# 118090    78000  ...  Auto Start Stop function, Bluetooth \ handsfre...
# 111729    78000  ...  Auto Start Stop function, Bluetooth \ handsfre...
#
#                                             OtherFeatures  \
# 58549   4x4, Напълно обслужен, С регистрация, Сервизна...
# 50549   4x4, Напълно обслужен, С регистрация, Сервизна...
# 65551                                 4x4, Бартер, Лизинг
# 58827                                 4x4, Бартер, Лизинг
# 40149                          Напълно обслужен, Нов внос
# ...                                                   ...
# 77725   4x4, 7 места, Дълга база, Напълно обслужен, С ...
# 90478         Напълно обслужен, Нов внос, Сервизна книжка
# 117945        Напълно обслужен, Нов внос, Сервизна книжка
# 118090  Buy back, Бартер, Лизинг, Нов внос, Сервизна к...
# 111729  Buy back, Бартер, Лизинг, Нов внос, Сервизна к...
#
#                                          ExteriorFeatures  \
# 58549                    4(5) Врати, Лети джанти, Металик
# 50549                    4(5) Врати, Лети джанти, Металик
# 65551                                                 NaN
# 58827                                                 NaN
# 40149   4(5) Врати, LED фарове, Лети джанти, Металик, ...
# ...                                                   ...
# 77725   4(5) Врати, Ксенонови фарове, Лети джанти, Мет...
# 90478   4(5) Врати, Лети джанти, Металик, Халогенни фа...
# 117945  4(5) Врати, Ксенонови фарове, Лети джанти, Мет...
# 118090  2(3) Врати, LED фарове, Ксенонови фарове, Лети...
# 111729  2(3) Врати, LED фарове, Ксенонови фарове, Лети...
#
#                            SecurityFeatures InteriorFeatures  \
# 58549   Аларма, Каско, Централно заключване      Кожен салон
# 50549   Аларма, Каско, Централно заключване      Кожен салон
# 65551                                   NaN              NaN
# 58827                                   NaN              NaN
# 40149                                Аларма      Кожен салон
# ...                                     ...              ...
# 77725          Аларма, Централно заключване      Кожен салон
# 90478          Аларма, Централно заключване      Кожен салон
# 117945         Аларма, Централно заключване      Кожен салон
# 118090         Аларма, Централно заключване    Велурен салон
# 111729         Аларма, Централно заключване    Велурен салон
#
#        SpecialisedFeatures          Region          City ViewCount  \
# 58549                  NaN           София     гр. София      2849
# 50549                  NaN           София     гр. София      2850
# 65551                  NaN           София     гр. София      1228
# 58827                  NaN           София     гр. София      1220
# 40149                  NaN           София     гр. София      1733
# ...                    ...             ...           ...       ...
# 77725                  NaN  Велико Търново  с. Беляковец       676
# 90478                  NaN          Сливен    гр. Сливен       133
# 117945                 NaN          Сливен    гр. Сливен        84
# 118090                 NaN           София   гр. Самоков      5873
# 111729                 NaN           София   гр. Самоков      8548
#
#                                                OfferTitle
# 58549                           BMW 530E xDrive, M, Laser
# 50549                           BMW 530E xDrive, M, Laser
# 65551              Mercedes-Benz S 450 L 4мatic Exclusive
# 58827              Mercedes-Benz S 450 L 4мatic Exclusive
# 40149                      BMW 330 I, M PAKET, PANO, LED,
# ...                                                   ...
# 77725                                 Volvo Xc90 R-DESIGN
# 90478                               Volvo V40 (КАТО НОВА)
# 117945                Volvo V40 Cross Country (KATO НОВА)
# 118090         Fiat 500 595 NAVI BEATS EVRO 6D 78000KM!!!
# 111729  Abarth 595 NAVI BEATS KLIMATRONIK EVRO 6D 7800...
#
# [4019 rows x 26 columns]

# %%
duplicate_vin_rows['Make'].unique()
# Out:
# array(['BMW', 'Mercedes-Benz', 'Audi', 'Citroen', 'Ford', 'Kia', 'VW',
#        'Renault', 'Opel', 'Daimler', 'Infiniti', 'DS', 'Seat', 'Nissan',
#        'Subaru', 'Skoda', 'Cupra', 'Hyundai', 'Mazda', 'Toyota', 'Volvo',
#        'Dacia', 'Jaguar', 'Peugeot', 'Tesla', 'Honda', 'Land Rover',
#        'Maybach', 'Abarth', 'Alpina', 'Fiat'], dtype=object)

# %%
duplicated_columns = data.columns.difference(['ViewCount', 'OfferTitle', 'Model'])
duplicated_columns
# Out:
# Index(['BatteryCapacity (EV)', 'BodyType', 'City', 'Color', 'ComfortFeatures',
#        'EngineSize', 'EuroStandard', 'ExteriorFeatures', 'FuelType',
#        'Horsepower', 'InteriorFeatures', 'Make', 'ManufactureDate', 'Mileage',
#        'MilesPerFullCharge (EV)', 'OtherFeatures', 'Price', 'Region',
#        'SafetyFeatures', 'SecurityFeatures', 'SpecialisedFeatures',
#        'Transmission', 'VIN'],
#       dtype='object')

# %%
all_duplicates = data.duplicated(subset=duplicated_columns, keep=False)

data[all_duplicates].sort_values(by='Model')
# Out:
#            Make    Model BodyType ManufactureDate  FuelType Transmission  \
# 99890       BMW  1-серия   Хечбек         07/2005  Бензинов        Ръчна
# 100397      BMW  1-серия   Хечбек         06/2006   Дизелов        Ръчна
# 100398      BMW  1-серия   Хечбек         01/2005   Дизелов        Ръчна
# 100399      BMW  1-серия   Хечбек         12/2007   Дизелов        Ръчна
# 100400      BMW  1-серия   Хечбек         09/2005   Дизелов        Ръчна
# ...         ...      ...      ...             ...       ...          ...
# 28257      Opel   Zafira  Миниван         09/2006  Бензинов        Ръчна
# 43747   Citroen       Zx    Комби         04/1994  Бензинов        Ръчна
# 43746   Citroen       Zx    Комби         04/1994  Бензинов        Ръчна
# 63871     Mazda     СХ-3     Джип         06/2015  Бензинов  Автоматична
# 63918     Mazda     СХ-3     Джип         06/2015  Бензинов  Автоматична
#
#        EngineSize  Horsepower EuroStandard  Mileage  ...  \
# 99890        1600         116          NaN   260000  ...
# 100397       2000         163       Евро 4   168000  ...
# 100398       2000         163       Евро 3   260000  ...
# 100399        NaN         143       Евро 4   172000  ...
# 100400       2000         163       Евро 4   204000  ...
# ...           ...         ...          ...      ...  ...
# 28257        1800         140       Евро 3   325100  ...
# 43747         NaN          74          NaN   280000  ...
# 43746         NaN          74          NaN   280000  ...
# 63871        2000         150       Евро 6   118000  ...
# 63918        2000         150       Евро 6   118000  ...
#
#                                           ComfortFeatures  \
# 99890   Ел. Огледала, Ел. Стъкла, Климатик, Регулиране...
# 100397  Auto Start Stop function, Бордкомпютър, Датчик...
# 100398  Auto Start Stop function, USB, audio\video, IN...
# 100399  Bluetooth \ handsfree система, USB, audio\vide...
# 100400  USB, audio\video, IN\AUX изводи, Бордкомпютър,...
# ...                                                   ...
# 28257   Бордкомпютър, Ел. Огледала, Климатроник, Навиг...
# 43747                                Ел. Стъкла, Климатик
# 43746                                Ел. Стъкла, Климатик
# 63871   Auto Start Stop function, Bluetooth \ handsfre...
# 63918   Auto Start Stop function, Bluetooth \ handsfre...
#
#                                             OtherFeatures  \
# 99890                                       С регистрация
# 100397                                           Нов внос
# 100398                                      С регистрация
# 100399          Бартер, Лизинг, Нов внос, Сервизна книжка
# 100400                                      С регистрация
# ...                                                   ...
# 28257   7 места, Газова уредба, Дълга база, Сервизна к...
# 43747                                                 NaN
# 43746                                                 NaN
# 63871              4x4, Лизинг, Нов внос, Сервизна книжка
# 63918              4x4, Лизинг, Нов внос, Сервизна книжка
#
#                                          ExteriorFeatures  \
# 99890   4(5) Врати, LED фарове, Лети джанти, Металик, ...
# 100397  4(5) Врати, Лети джанти, Металик, Халогенни фа...
# 100398                                         4(5) Врати
# 100399  4(5) Врати, Лети джанти, Металик, Халогенни фа...
# 100400  4(5) Врати, Лети джанти, Металик, Халогенни фа...
# ...                                                   ...
# 28257                    4(5) Врати, Лети джанти, Металик
# 43747                                                 NaN
# 43746                                                 NaN
# 63871   4(5) Врати, LED фарове, Ксенонови фарове, Лети...
# 63918   4(5) Врати, LED фарове, Ксенонови фарове, Лети...
#
#                     SecurityFeatures InteriorFeatures SpecialisedFeatures  \
# 99890           Централно заключване    Велурен салон                 NaN
# 100397          Централно заключване              NaN                 NaN
# 100398          Централно заключване              NaN                 NaN
# 100399  Аларма, Централно заключване              NaN                 NaN
# 100400   Каско, Централно заключване              NaN                 NaN
# ...                              ...              ...                 ...
# 28257   Аларма, Централно заключване              NaN                 NaN
# 43747                            NaN              NaN                 NaN
# 43746                            NaN              NaN                 NaN
# 63871   Аларма, Централно заключване      Кожен салон                 NaN
# 63918   Аларма, Централно заключване      Кожен салон                 NaN
#
#            Region           City ViewCount  \
# 99890        Русе       гр. Русе       990
# 100397      Враца      гр. Враца      2002
# 100398  Кюстендил  гр. Кюстендил       608
# 100399       Русе       гр. Русе       330
# 100400     Плевен     гр. Плевен       175
# ...           ...            ...       ...
# 28257     Монтана    гр. Монтана       115
# 43747       Ямбол      гр. Ямбол       780
# 43746       Ямбол      гр. Ямбол       165
# 63871       София      гр. София      4694
# 63918       София      гр. София      1146
#
#                                                OfferTitle
# 99890                                             BMW 116
# 100397                               BMW 120 2.0TDI 163кс
# 100398                                            BMW 120
# 100399                                BMW 120 2.0D-143к.с
# 100400                                       BMW 120 120D
# ...                                                   ...
# 28257             Opel Zafira Zafira B 1.8 benzin Gas LPG
# 43747                     Citroen Zx 1.4 на газ с паспорт
# 43746                                      Citroen Zx 1.4
# 63871   Mazda СХ-3 2.0i,150кс,Автомат,Нави,Камера,Кожа...
# 63918   Mazda СХ-3 2.0i,150кс,Автомат,Нави,Камера,Кожа...
#
# [39331 rows x 26 columns]

# %%
before_drop_rows = data.shape[0]
print(f'Before removing duplicates: {before_drop_rows}')

data = data.drop_duplicates(subset=duplicated_columns, keep='last')
nan_rows = data.loc[data['VIN'].isna()]
data = data.drop_duplicates(subset=['VIN'], keep='last')
data = data.merge(nan_rows, how='outer')

print(f'{before_drop_rows - data.shape[0]} duplicates removed')
# Out:
# Before removing duplicates: 119525
# 19832 duplicates removed

# %%
# No Duplicates!! :)
data[data.duplicated(subset=duplicated_columns, keep=False)], data[data.duplicated(subset='VIN', keep=False)]
# Out:
# (Empty DataFrame
#  Columns: [Make, Model, BodyType, ManufactureDate, FuelType, Transmission, EngineSize, Horsepower, EuroStandard, Mileage, MilesPerFullCharge (EV), BatteryCapacity (EV), Color, VIN, Price, SafetyFeatures, ComfortFeatures, OtherFeatures, ExteriorFeatures, SecurityFeatures, InteriorFeatures, SpecialisedFeatures, Region, City, ViewCount, OfferTitle]
#  Index: []
#
#  [0 rows x 26 columns],
#           Make Model        BodyType ManufactureDate      FuelType  \
#  0      Abarth   595             Ван         07/1997       Дизелов
#  1      Abarth   595          Кабрио         05/2018      Бензинов
#  2      Abarth   595          Кабрио         07/2011      Бензинов
#  4      Abarth   595          Кабрио         09/2012      Бензинов
#  5      Abarth   595          Кабрио         12/2017      Бензинов
#  ...       ...   ...             ...             ...           ...
#  99688   Други  Друг           Седан         05/1983       Дизелов
#  99689   Други  Друг  Стреч лимузина         01/2022  Електрически
#  99690   Други  Друг  Стреч лимузина         05/2012  Електрически
#  99691   Други  Друг          Хечбек         02/1937      Бензинов
#  99692   Чайка     М  Стреч лимузина         05/1986      Бензинов
#
#        Transmission EngineSize  Horsepower EuroStandard  Mileage  ...  \
#  0            Ръчна         16         700       Евро 2      555  ...
#  1            Ръчна       1400         163       Евро 6    19500  ...
#  2      Автоматична        NaN         140       Евро 6   117000  ...
#  4      Автоматична       1368         160          NaN   111000  ...
#  5            Ръчна        NaN         160       Евро 6    48000  ...
#  ...            ...        ...         ...          ...      ...  ...
#  99688        Ръчна       6500         200       Евро 1   543677  ...
#  99689  Автоматична        NaN        <NA>          NaN        1  ...
#  99690  Автоматична        NaN        <NA>          NaN     1112  ...
#  99691        Ръчна       2300          55       Евро 1    42000  ...
#  99692  Автоматична        NaN         220          NaN    83999  ...
#
#                                           ComfortFeatures  \
#  0                                                    NaN
#  1                                                    NaN
#  2      USB, audio\video, IN\AUX изводи, Ел. Стъкла, Е...
#  4      Bluetooth \ handsfree система, Steptronic, Tip...
#  5      Auto Start Stop function, Bluetooth \ handsfre...
#  ...                                                  ...
#  99688                                                NaN
#  99689                    USB, audio\video, IN\AUX изводи
#  99690                                                NaN
#  99691                                                NaN
#  99692                Ел. Стъкла, Климатик, Стерео уредба
#
#                                             OtherFeatures  \
#  0                                                    NaN
#  1       Напълно обслужен, С регистрация, Сервизна книжка
#  2                       Бартер, Лизинг, Нов внос, Тунинг
#  4                          Бартер, Лизинг, С регистрация
#  5      Buy back, Лизинг, Нов внос, Сервизна книжка, Т...
#  ...                                                  ...
#  99688                                                NaN
#  99689                                         Дълга база
#  99690                                                NaN
#  99691                                                NaN
#  99692  7 места, Бартер, Дълга база, Лизинг, Напълно о...
#
#                                          ExteriorFeatures  \
#  0                                                    NaN
#  1                                             2(3) Врати
#  2                                                    NaN
#  4      2(3) Врати, Ксенонови фарове, Лети джанти, Мет...
#  5      2(3) Врати, LED фарове, Ксенонови фарове, Лети...
#  ...                                                  ...
#  99688                                                NaN
#  99689                                         LED фарове
#  99690                                                NaN
#  99691                                                NaN
#  99692                                         4(5) Врати
#
#                     SecurityFeatures            InteriorFeatures  \
#  0                               NaN                         NaN
#  1       Каско, Централно заключване                 Кожен салон
#  2              Централно заключване                 Кожен салон
#  4       Каско, Централно заключване                 Кожен салон
#  5      Аларма, Централно заключване  Велурен салон, Кожен салон
#  ...                             ...                         ...
#  99688                           NaN                         NaN
#  99689                           NaN                 Кожен салон
#  99690                           NaN                         NaN
#  99691                           NaN                         NaN
#  99692                           NaN               Велурен салон
#
#        SpecialisedFeatures   Region         City ViewCount  \
#  0                     NaN    София    гр. София       229
#  1                     NaN    София    гр. София       199
#  2                     NaN    София    с. Волуяк      5359
#  4                     NaN    София    гр. София      6095
#  5                     NaN    София  гр. Самоков     26720
#  ...                   ...      ...          ...       ...
#  99688                 NaN    София    гр. София       342
#  99689                 NaN   Бургас   гр. Бургас       186
#  99690                 NaN  Пловдив  гр. Пловдив     34418
#  99691                 NaN    Видин    гр. Видин      4479
#  99692                 NaN    София    гр. Годеч     14296
#
#                                                OfferTitle
#  0                                         Abarth 595 5.5
#  1                           Abarth 595 Turismo 1.4 T-Jet
#  2              Abarth 595 ABARTH 1.4 НОВ ВНОС ОТ ИСПАНИЯ
#  4                        Abarth 595 Competizione Turismo
#  5      Abarth 595 500 PISTA 595 CABRIO NAVI EVRO 6B 4...
#  ...                                                  ...
#  99688                                     Други Автокран
#  99689                                              Други
#  99690                                            Други Q
#  99691                                       Други Газ М1
#  99692                                         Чайка М 14
#
#  [89660 rows x 26 columns])

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Make, Model, BodyType, ManufactureDate, FuelType, Transmission, EngineSize, Horsepower, EuroStandard, Mileage, MilesPerFullCharge (EV), BatteryCapacity (EV), Color, VIN, Price, SafetyFeatures, ComfortFeatures, OtherFeatures, ExteriorFeatures, SecurityFeatures, InteriorFeatures, SpecialisedFeatures, Region, City, ViewCount, OfferTitle]
# Index: []
#
# [0 rows x 26 columns]

# %%
print(f'Final shape: {data.shape}')
print(f'Final columns: {data.columns}')
# Out:
# Final shape: (99693, 26)
# Final columns: Index(['Make', 'Model', 'BodyType', 'ManufactureDate', 'FuelType',
#        'Transmission', 'EngineSize', 'Horsepower', 'EuroStandard', 'Mileage',
#        'MilesPerFullCharge (EV)', 'BatteryCapacity (EV)', 'Color', 'VIN',
#        'Price', 'SafetyFeatures', 'ComfortFeatures', 'OtherFeatures',
#        'ExteriorFeatures', 'SecurityFeatures', 'InteriorFeatures',
#        'SpecialisedFeatures', 'Region', 'City', 'ViewCount', 'OfferTitle'],
#       dtype='object')

# %%
data.columns
# Out:
# Index(['Make', 'Model', 'BodyType', 'ManufactureDate', 'FuelType',
#        'Transmission', 'EngineSize', 'Horsepower', 'EuroStandard', 'Mileage',
#        'MilesPerFullCharge (EV)', 'BatteryCapacity (EV)', 'Color', 'VIN',
#        'Price', 'SafetyFeatures', 'ComfortFeatures', 'OtherFeatures',
#        'ExteriorFeatures', 'SecurityFeatures', 'InteriorFeatures',
#        'SpecialisedFeatures', 'Region', 'City', 'ViewCount', 'OfferTitle'],
#       dtype='object')

# %%
print(f'Final dtypes:')
data.dtypes
# Out:
# Final dtypes:
# Make                        object
# Model                       object
# BodyType                    object
# ManufactureDate             object
# FuelType                    object
# Transmission                object
# EngineSize                  object
# Horsepower                   Int64
# EuroStandard                object
# Mileage                      Int64
# MilesPerFullCharge (EV)    Float64
# BatteryCapacity (EV)       Float64
# Color                       object
# VIN                         object
# Price                       object
# SafetyFeatures              object
# ComfortFeatures             object
# OtherFeatures               object
# ExteriorFeatures            object
# SecurityFeatures            object
# InteriorFeatures            object
# SpecialisedFeatures         object
# Region                      object
# City                        object
# ViewCount                    int64
# OfferTitle                  object
# dtype: object

# %%
data.to_csv('./data/bg-car-offers.csv', index=False)
